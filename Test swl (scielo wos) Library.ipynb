# %%
import swl
from pathlib import Path

# %% [markdown]
# # Define the data folder

# %%
data_folder = Path('Data_All')/'epidemiology-scielo'
#data_folder = Path('Data_All')/'microbiology-wos'

# %% [markdown]
# # Read the folder and create a data frame

# %%
df=swl.ingest_folder('scielo', data_folder=data_folder)
# Out:
# Data Folder exists:  26  files
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (1).txt
# Encoding unknown. Checking Encoding
# Encoding:  UTF-8-SIG
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (10).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (11).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (12).txt
# 475
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (13).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (14).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (15).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (16).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (17).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (18).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (19).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (2).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (20).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (21).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (22).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (23).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (24).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (25).txt
# 146
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (3).txt
# 475
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (4).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (5).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (6).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (7).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (8).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs (9).txt
# 500
# * Ingesting file:  Data_All/epidemiology-scielo/savedrecs.txt
# 500

# %% [markdown]
# # Create the dictionaries

# %%
 authors, papers, institutions = swl.get_scielo_dicts(df)
# Out:
# Country: Hospital San José not in database
# Country: Fundación Universitaria de Ciencias de la Salud not in database
# Country:  not in database
# Country: Secretaría de Salud de Medellín not in database
# Country: Sociedad Argentina de Terapia Intensiva (SATI) not in database
# Country: Sociedad Argentina de Infectología (SADI) not in database
# Country: Museo Argentino de Ciencias Naturales “Bernardino Rivadavia” not in database
# Country: Ministerio de Salud de Nación not in database
# Country: Universidad Nacional de La Plata not in database
# Country: Hospital de Agudos “Dr. Juan A. Fernández” not in database
# Country: Hospital de Infecciosas “Dr. Francisco Javier Muñiz” not in database
# Country: Hospital de Pediatría “Dr. Ricardo Gutiérrez” not in database
# Country: University of Alberta not in database
# Country: SELADIS FCFB-UMSA not in database
# Country: Universidad Mayor de san Andrés not in database
# Country: Universidad del Tolima not in database
# Country: Hospital Nacional de Niños Dr. Carlos Sáenz Herrera not in database
# Country: Laboratorio TamizMas de Químicos Maldonado not in database
# Country: Complejo Hospitalario de Navarra not in database
# Country: Universidad Centro Occidental Lisandro Alvarado not in database
# Country: Smith & Nephew Iberia not in database
# Country: Grupo Nacional para el Estudio y Asesoramiento en Úlceras por Presión y Heridas Crónicas (GNEAUPP) not in database
# Country: Coordinación Regional de Zoonosis not in database
# Country: Universidad del Zulia not in database
# Country: UNC not in database
# Country: Particular not in database
# Country: Cesalp-Instituto Médico Platense not in database
# Country: Universidad Cooperativa de Colombia not in database
# Country: Universidad Cooperativa de Colombia; Universidad Cooperativa de Colombia not in database
# Country: Universidad Católica San Antonio de Murcia not in database
# Country: Murcia not in database
# Country: Salud Mental de Murcia not in database
# Country: Área de Continuidad de Cuidados de Atención Primaria Area VII not in database
# Country: The University of Texas School of Public Health not in database
# Country: Universitat Autònoma de Barcelona not in database
# Country: Hospital General Docente Abel Santamaría Cuadrado not in database
# Country: Centro Municipal para el Desarrollo de la Genética Comunitaria not in database
# Country: Facultad de Ciencias Médicas Enrique Cabrera not in database
# Country: Área de Gestión Sanitaria Norte de Cádiz not in database
# Country: Distrito de Atención Primaria Bahía de Cádiz-La Janda not in database
# Country: Área de Gestión Sanitaria Campo de Gibraltar not in database
# Country: Provincia de Rio Negro not in database
# Country: University of São Paulo City not in database
# Country: UNICID not in database
# Country: Hospital Nacional Dos de Mayo not in database
# Country: Hospital de Niños Ricardo Gutiérrez not in database
# Country: Izmir Katip Celebi University not in database
# Country: Instituto Nacional de Enfermedades Respiratorias Ismael Cosío Villegas not in database
# Country: Universidad de Valladolid not in database
# Country: Universidad Autónoma de Baja California not in database
# Country: Asociación Salvadoreña de Periodoncia not in database
# Country: Policlínico Universitario Manuel Piti Fajardo not in database
# Country: Sociedad Española de Epidemiología not in database
# Country: Sociedad Argentina de Cardiología not in database
# Country: Hospital Cutral Co not in database
# Country: BioMedware not in database
# Country: Cuban Society of Clinical Nutrition and Metabolism not in database
# Country: Hospital General Pediátrico Niños de Acosta Ñu. Reducto not in database
# Country: Universidad de Ciencias Médicas de la Habana not in database
# Country: Ayuntamiento de Madrid not in database
# Country: Hospital Universitario de Móstoles not in database
# Country: Instituto de Salud Carlos III not in database
# Country: SMC-AS not in database
# Country: Secretaría de Salud de Casanare not in database
# Country: Hospital Universitario Abel Santamaría Cuadrado. Pinar del Río. Cuba not in database
# Country: Policlínico Universitario Hermanos Cruz. Pinar del Río. Cuba not in database
# Country: Salud. Pinar del Río. Cuba not in database
# Country: Universidad de Pinar del Río. Cuba not in database
# Country: El Colegio de la Frontera Sur not in database
# Country: Universidad Juárez Autónoma de Tabasco not in database
# Country: Instituto del Diagnóstico not in database
# Country: Hospital José María Cullen not in database
# Country: Sanatorio Garay not in database
# Country: Clínica de Nefrología y Enfermedades Cardiovasculares not in database
# Country: Sanatorio San Jerónimo not in database
# Country: Sagrada Familia not in database
# Country: Centro Médico de Especialidades Pediátricas (CEMEP) not in database
# Country: Hospital Regional not in database
# Country: Hospital Universitario San Cecilio not in database
# Country: Servicio Andaluz de Salud not in database
# Country: Clínica cardioVID not in database
# Country: UNICAMP not in database
# Country: UFRGS not in database
# Country: Embrapa Agroindústria Tropical not in database
# Country: Unesp not in database
# Country: CREMERJ not in database
# Country: Hospital Británico not in database
# Country: Universidad de la República UDELAR not in database
# Country: S.A. Instituto de Altos Estudios Dr. Arnoldo Gabaldon not in database
# Country: Corporación Colombiana de Investigación Agropecuaria not in database
# Country: Unidad Docente de Medicina Preventiva y Salud Pública de la Región de Murcia not in database
# Country: Secretaria do Estado de Saúde do Maranhão not in database
# Country: Colombia; Universidad Pontificia Bolivariana not in database
# Country: Hospital Prof. A. Posadas not in database
# Country: Universidad Rey Juan Carlos not in database
# Country: Hospital de Fuenlabrada not in database
# Country: Real Academia de Medicina y Cirugía de Valladolid not in database
# Country: Universidade Federal de Maringá not in database
# Country: UFV not in database
# Country: Instituto do Rim de Maringa not in database
# Country: Clinica do Rim de Maringa not in database
# Country: UdelaR not in database
# Country: CeSAC 18 not in database
# Country: Hospital Universitario Puerta de Hierro not in database
# Country: Centro de Investigación y Estudios en Cultura y Sociedad not in database
# Country: Instituto Nacional de Perinatología Isidro Espinosa de los Reyes not in database
# Country: Instituto Nacional de Ciencias Genómicas not in database
# Country: Centro de Imunoalergologia not in database
# Country: Tanzania Veterinary Laboratory Agency not in database
# Country: Central Veterinary Research Institute not in database
# Country: Institute for Animal Health not in database
# Country: Royal Veterinary College not in database
# Country: Policlínico Universitario Fermín Valdés Domínguez not in database
# Country: Fundación Instituto de Investigación en Servicios de Salud not in database
# Country: Consejo Superior de Investigaciones Científicas (CSIC) not in database
# Country: Hospital de la Santa Creu i Sant Pau not in database
# Country: Universidad de Guadalajara not in database
# Country: Sociedad Española de Medicina Rural y Generalista (AP) (SEMERGEN) not in database
# Country: Sociedad Española de Hipertensión Arterial-Liga Lucha Contra la HTA (SEH-LELHA) not in database
# Country: Sociedad Española de Química Clínica (SEQC) not in database
# Country: Sociedad Española de Medicina de Familia y Comunitaria (AP) (SEMFyC) not in database
# Country: Sociedad Española de Médicos Generalistas (AP) (SEMG) not in database
# Country: UMSA not in database
# Country: UMSA not in database
# Country: Grupo de Estudio Multiprofesional en Salud del Adulto (GEMSA) not in database
# Country: Centro Nacional de Promoción Científica y Tecnológica (CNPq) 2 not in database
# Country: Universidad de Sonora not in database
# Country: El Colegio de Sonora not in database
# Country: Faculdade da Serra Gaúcha not in database
# Country: Supervisao de Vigilancia em Saude not in database
# Country: UNIFESP not in database
# Country: Mestre em medicina not in database
# Country: Faculdades Adamantinenses Integradas not in database
# Country: Embrapa Agroenergia not in database
# Country: Centro Hospitalario Pereira Rossell CHPR not in database
# Country: Aarhus Sygehus University Hospital not in database
# Country: Hospital General Pediátrico Niños de Acosta Ñu not in database
# Country: Universidad Autónoma de Yucatán not in database
# Country: Universidad Cristóbal Colón not in database
# Country: Universidad Veracruzana not in database
# Country: Hospital Regional de Veracruz not in database
# Country: Hospital General Nochixtlán Oaxaca not in database
# Country: Instituto Nacional de Perinatología not in database
# Country: Hospital de Niños not in database
# Country: Instituto Nacional de Salud Pública not in database
# Country: Universidad de Texas not in database
# Country: Policlínico de Trastornos Temporomandibulares y Dolor Orofacial not in database
# Country: Servicio Extremeño de Salud (SES) not in database
# Country: Universidad de Valencia not in database
# Country: Investigadora Adjunta del Centro de Investigación Genética del Instituto de Investigaciones Técnico Científicas de la Universidad Policial not in database
# Country: Perito Investigador del Centro de Investigación Genética del Instituto de Investigaciones Técnico Científicas de la Universidad Policial not in database
# Country: Investigador Instituto de Investigaciones Fármaco Bioquímicas not in database
# Country: Policlínica Docente Guaro. Mayarí not in database
# Country: Clínica Estomatológica Artemio Mastrapa not in database
# Country: Clínica Estomatológica René Guzmán Pérez not in database
# Country: Hospital Prof. Dr. Juan P. Garrahan not in database
# Country: Hospital Clínico Quirúrgico Dr. León Cuervo Rubio not in database
# Country: Policlínico Universitario Pedro Borras Astorga not in database
# Country: Hospital Heliópolis not in database
# Country: Hospital Dr. Carlos G. Durand not in database
# Country: Departamento de Pediatría. Hospital Nacional de Itaugua Guazú not in database
# Country: Hospital Ignacio Pirovano not in database
# Country: Grupo de Apoyo Pedagógico y Formación Docente not in database
# Country: PhD not in database
# Country: Universidad Nacional del Sur not in database
# Country: ACES de Matosinhos not in database
# Country: Instituto Estatal de Cancerología not in database
# Country: Universidade Gama Filho not in database
# Country: Federal University of Goiás not in database
# Country: National Institute for Translational Medicine (INCT-TM) not in database
# Country: Goiás State University not in database
# Country: UFG not in database
# Country: Mozambique; Jeroen Bosch Hospital not in database
# Country: Jeroen Bosch Academy not in database
# Country: Jeroen Bosch Hospital not in database
# Country: UFSCar not in database
# Country: Servicio de Diagnóstico de Leptospirosis de la Facultad de Ciencias Veterinarias not in database
# Country: Hospital Provincial Pediátrico Pepe Portilla not in database
# Country: Hospital Clínico Quirúrgico León Cuervo Rubio not in database
# Country: Hospital Nacional de Niños not in database
# Country: Hospital San Rafael de Alajuela not in database
# Country: Grupo B de Colciencias not in database
# Country: Hospital Dr. Isidro de Armas Rodríguez not in database
# Country: Policlínico Comunitario Dr. Modesto Gómez Rubio not in database
# Country: Municipalidad de Bahía Blanca not in database
# Country: CENPALAB not in database
# Country: Instituto de Salud del Estado de México not in database
# Country: Hospital Universitario Dr.Negrín not in database
# Country: Unidad de Cuidado Intensivo Quirúrgico not in database
# Country: Residente de Anestesiología not in database
# Country: Residente de Otorrinolaringología not in database
# Country: Universidad de Iberoamérica not in database
# Country: University Juan A. Maza not in database
# Country: Parassitarie ed Immunomediate not in database
# Country: Universidade de Córdoba not in database
# Country: Consejo de Administración de Arrythmia Alliance not in database
# Country: Sociedad Iberoamericana de Enfermedad Cerebrovascular not in database
# Country: American Foundation for Women's Health not in database
# Country: UNESP not in database
# Country: Hermes Pardini not in database
# Country: University of Houston not in database
# Country: Nephrocare España not in database
# Country: Centro Médico Clínica Bucaramanga not in database
# Country: Epidemióloga not in database
# Country: Unidad de Ortopedia Hospital Central de la Policía not in database
# Country: Universidad Nacional not in database
# Country: Faculdade Assis Gurgacz (FAG) not in database
# Country: Hospital Central Dr.Ignacio Morones Prieto not in database
# Country: Consorci Sanitari Parc Taulí not in database
# Country: Fundación Hospitalaria not in database
# Country: Hospital Nacional 'Prof. Alejandro Posadas' not in database
# Country: Hospital General de Agudos 'Carlos G. Durand' not in database
# Country: Hospital de Niños. 'Víctor V.J. Vilela' not in database
# Country: Hospital Pediátrico Notti de Mendoza not in database
# Country: Hospital de Pediatría 'Prof. J.P. Garrahan' not in database
# Country: Sanatorio Güemes not in database
# Country: Hospital Universitario Austral not in database
# Country: Universidad de Buenos Aires (Argentina) not in database
# Country: AWR) not in database
# Country: Hospital Edmundo Vasconcelos not in database
# Country: Sanofi Pasteur not in database
# Country: Fundação de Medicina Tropical not in database
# Country: División de Cirugía Pediátrica not in database
# Country: Sanjay Gandhi Post Graduate Institute of Medical Sciences not in database
# Country: Central Connecticut State University not in database
# Country: Hospital Italiano de Buenos Aires not in database
# Country: Docencia e Investigación Clínica (GEDIC) not in database
# Country: Municipalidad de Guácimo not in database
# Country: Centro Nacional de Investigación disciplinaria en fisiología y Mejoramiento Animal not in database
# Country: Desarrollo Rural Pesca y Alimentación not in database
# Country: U.D.C.A not in database
# Country: Sociedad Uruguaya de Cardiología not in database
# Country: Médica Uruguay not in database
# Country: Sanatorio Americano not in database
# Country: Universidad Rafael Núñez not in database
# Country: University of Kentucky not in database
# Country: Saint Louis Université Paris VII not in database
# Country: Hospital General de Niños Dr. Pedro de Elizalde not in database
# Country: Fundação IMEPEN not in database
# Country: UCB not in database
# Country: UFJF not in database
# Country: State University of Maringá not in database
# Country: State University of Londrina not in database
# Country: American Foundation for Women´s Health not in database
# Country: Atrial Fibrillation Association not in database
# Country: Laboratório de Genética e Biologia Molecular not in database
# Country: PIBIC not in database
# Country: Hospital SAMCO not in database
# Country: Corporación Médica de San Martín not in database
# Country: Embrapa Arroz e Feijão not in database
# Country: PUC not in database
# Country: Instituto de Medicina Veterinaria not in database
# Country: Unidad Municipal de Salud Norte Patronato San José not in database
# Country: KZN Department of Health not in database
# Country: Howard not in database
# Country: Agrupamento de Centros de Saúde Porto Ocidental not in database
# Country: ICVS/3B´s Laboratório Associado not in database
# Country: Instituto de Ciências Humanas not in database
# Country: Arrhythmia Alliance not in database
# Country: Instituto sobre Alcoholismo y Farmacodependencia not in database
# Country: Agência Paulista de Tecnologia dos Agronegócios not in database
# Country: Universidad de Arquitectura not in database
# Country: Instituto de Cardiología not in database
# Country: Doctora en Bioquímica-Epidemióloga not in database
# Country: Hospital Nacional not in database
# Country: Consorcio de Investigación Biomédica de Epidemiología y Salud Pública (CIBERESP) not in database
# Country: Universidad Santiago de Cali (Palmira) not in database
# Country: Universitat de Rovira i Virgili not in database
# Country: Clínica Carlos Ardila Lule (FOSCAL) not in database
# Country: Escuela Nacional de Antropología e Historia not in database
# Country: Sociedade Brasileira de Urologia not in database
# Country: Consorcio de Investigación Biomédica en Red (CIBER) Enfermedades Respiratorias not in database
# Country: Hospital Parc Taulí not in database
# Country: Hospital Juan XXIII not in database
# Country: American College of Cardiology Foundation not in database
# Country: SES-RS not in database
# Country: HUB not in database
# Country: Pan American Federation of Endocrinology not in database
# Country: Prefeitura Municipal de Fortaleza not in database
# Country: ADRA Angolana Acción para el Desarrollo Rural y Ambiente not in database
# Country: Dirección General del Instituto de los Servicios de Veterinaria not in database
# Country: Imagen y Opinión Pública (CIMOP) not in database
# Country: Conselleria de Sanitat de Valencia not in database
# Country: Universitat de València not in database
# Country: Universidad Jaume I de Castellón not in database
# Country: Hospital Universitario Dr. Josep Trueta not in database
# Country: Intituto Politécnico do Cávado e Ave not in database
# Country: Instituto de Biologia Celular e Molecular not in database
# Country: Kalafong Hospital not in database
# Country: Armed Forces Research Institute of Medical Science not in database
# Country: Royal Thai Army Nursing College not in database
# Country: Army Institute of Pathology not in database
# Country: Phramongkutklao College of Medicine not in database
# Country: Prefeitura Municipal de Lábrea not in database
# Country: Departamento de Salud de La Paz not in database
# Country: Centro de Salud Almanjayar not in database
# Country: Unidad de Investigación not in database
# Country: Morgan State University not in database
# Country: Universidad de Castilla-La Marcha not in database
# Country: University of Geneva not in database
# Country: British Polio Fellowship not in database
# Country: Universidad de Salamanca not in database
# Country: Servicio de Urgencias de Atención Primaria de Alhama not in database
# Country: Hospital Virgen de las Montañas de Villamantín not in database
# Country: Instituto Nacional de Investigaciones Agrícolas not in database
# Country: ARC-Onderstepoort Veterinary Institute not in database
# Country: Medicina Interna Universidad Libre Cali not in database
# Country: IPS Neurólogos de Occidente not in database
# Country: Universidad Libre Seccional Cali not in database
# Country: Pesquisas e Tratamento em Nefrologia not in database
# Country: Universidad de Ciencias Médicas de Matanzas Dr. Juan Guiteras Gener not in database
# Country: Instituto de Medicina Veterinaria Provincial not in database
# Country: Corporación Universitaria del Caribe not in database
# Country: Benemérita Universidad Autónoma de Puebla not in database
# Country: TB/HIV Care Association not in database
# Country: Instituto de Medicina Preventiva de la Defensa not in database
# Country: Médico Oftalmólogo. Asistente del Servicio de Oftalmología del Hospital Nacional Cayetano Heredia not in database
# Country: Secretaria Municipal de Saúde de Montes Claros not in database
# Country: Centro de Vigilância Epidemiológica de Foz do Iguaçu not in database
# Country: Brazilian Agricultural Research Corporation not in database
# Country: Instituto de Pesquisa Clínica Evandro Chagas not in database
# Country: Latin American Antibiotic Use in Intensive Care Unit Group not in database
# Country: Filial Provincial de Estomatología not in database
# Country: Clínica Estomatológica Provincial Antonio Briones Montoto not in database
# Country: Centro de Sueño Fundación Sueño Vigilia not in database
# Country: UFRA not in database
# Country: Acquaimagem Serviços em Aquicultura not in database
# Country: University of Porto Medical School not in database
# Country: Hospital Infection Control Committee not in database
# Country: Brasília University not in database
# Country: Hospital de Base not in database
# Country: Faculdade de São Luís do Maranhão not in database
# Country: Laboratório de Malária not in database
# Country: Centro Latino Americano de Investigación en Malaria not in database
# Country: Sanatorio San Carlos not in database
# Country: Fundación GESICA not in database
# Country: Distrito SAC Bariloche not in database
# Country: Hospital Zonal Bariloche not in database
# Country: Estación de Protección de Plantas de Yaguaramas not in database
# Country: Hospital Araújo Jorge not in database
# Country: Sede Universitaria not in database
# Country: Hospital Quinta Door not in database
# Country: Casa de Saúde e Maternidade Santa Martha not in database
# Country: Hospital de Emergencias Pediátricas not in database
# Country: Hospital General de Agudos Carlos G. Durand not in database
# Country: Hospital Pediátrico Notti not in database
# Country: Hospital de Niños Víctor V.J. Vilela not in database
# Country: Hospital de Pediatría Prof. J.P. Garrahan not in database
# Country: Ignacio Chávez not in database
# Country: Beneficência Portuguesa Hospital not in database
# Country: Unifesp not in database
# Country: Corposalud not in database
# Country: Insalud not in database
# Country: ISCMPA not in database
# Country: SESRS not in database
# Country: J. Maiztegui not in database
# Country: Sanatorio Julio Méndez not in database
# Country: Ministerio de Salud Pública de la Provincia del Chaco not in database
# Country: Ministerio de Desarrollo Humano de la Provincia de Formosa not in database
# Country: Universidad Nacional de Colombia; Universidad Nacional de Colombia not in database
# Country: Clínica Nuestra Señora del Rosario de Albacete not in database
# Country: Centro de Salud zona V de Albacete not in database
# Country: Centro de Salud Casas de Juan Núñez not in database
# Country: Centro de Salud zona III de Albacete not in database
# Country: Instituto de Seguridad Social del Estado de Tabasco not in database
# Country: Botswana Ministry of Health not in database
# Country: Hospital Virgen del Rocío not in database
# Country: Hospital Vall d'Hebron not in database
# Country: Ministerio de Salud de Tierra del Fuego not in database
# Country: Sociedad de Medicina Intensiva del Perú not in database
# Country: University of Buenos Aires not in database
# Country: Estado de São Paulo not in database
# Country: Hospital General Dr. Rafael Pascasio Gamboa not in database
# Country: Public Health Secretariat not in database
# Country: Mario Kroeff Hospital not in database
# Country: Diretoria de Vigilância Epidemiológica not in database
# Country: Faculdades Integradas Associação de Ensino de Santa Catarina not in database
# Country: São Paulo STD not in database
# Country: Instituto de Patologia de Araçatuba not in database
# Country: Hospital Ginecoobstétrico Dr. Julio R. Alfonso Medina not in database
# Country: Brazil; World Council of Enterostomal Therapists not in database
# Country: Policlínico Felipe Rodríguez Ramos not in database
# Country: Embrapa Cerrados not in database
# Country: Tropical Medicine Foundation of Amazonas not in database
# Country: Instituto Geral de Perícias not in database
# Country: Laboratório Dr. Arnaldo Buainain not in database
# Country: CIBER Enfermedades Respiratorias (CIBERes) not in database
# Country: Comunidad de Andalucía not in database
# Country: Red Española de Investigación en Patología Infecciosa (REIPI) not in database
# Country: Universidad Autónoma de Barcelona not in database
# Country: Agencia de Salud Pública de Barcelona not in database
# Country: Institut d'Investigació Biomèdica (IIB) Sant Pau not in database
# Country: Dirección de Atención Primaria de Navarra not in database
# Country: Servicio Navarro de Salud not in database
# Country: U. de Caldas not in database
# Country: Asociación Española 1ª de Socorros Mutuos not in database
# Country: Faculdade de Medicina Christus not in database
# Country: Harvard School of Public Health not in database
# Country: Centro Tecnológico do Exército not in database
# Country: Armani Consult SC Ltda not in database
# Country: Prefeitura Municipal de Votuporanga not in database
# Country: Holding Comunicações not in database
# Country: Prefeitura Municipal de Uberlândia not in database
# Country: Dirección Nacional de Maternidad not in database
# Country: Caja Nacional de Salud not in database
# Country: Piracicaba not in database
# Country: Hospital Regional Honorio Delgado not in database
# Country: Instituto Materno Perinatal not in database
# Country: Mesa de Concertación para la Lucha Contra la Pobreza not in database
# Country: Dirección Regional de Salud not in database
# Country: Sociedad Peruana de Obstetricia y Ginecología not in database
# Country: Hospital Regional de Ucayali not in database
# Country: Hospital Militar Regional del Norte not in database
# Country: Promsex not in database
# Country: Foro Regional por los Derechos Sexuales y Reproductivos not in database
# Country: DIRESA not in database
# Country: MIMDES not in database
# Country: Escuela de Medicina Hipólito Unanue not in database
# Country: Instituto de Endocrinología y Metabolismo not in database
# Country: Sequine Clínica Dermatológica not in database
# Country: Hospital Militar de Belém not in database
# Country: Colégio da Especialidade de Dermatologia not in database
# Country: Clínica Dermatológica Privada not in database
# Country: Clínica Dermatológica Dr. António Massa not in database
# Country: Fundación Mexicana para la Salud not in database
# Country: EUA not in database
# Country: Centro Sanitario Dr. San Martín not in database
# Country: Asociación Española Primera de Socorros Mutuos not in database
# Country: Hospital Policial not in database
# Country: Hospital Central de las Fuerzas Armadas not in database
# Country: IMBICE - CICPBA-CONICET not in database
# Country: Hospital Manuel Gea González not in database
# Country: Departamento de Sanidad Animal y Medicina Preventiva not in database
# Country: Servicio Autónomo Hospital Universitario de Maracaibo not in database
# Country: Laboratório de Virologia Molecular not in database
# Country: Centro de Atendimento Toxicológico not in database
# Country: Unidade Belo Horizonte not in database
# Country: Hospital Provincial de Pediatría Dr. F. Barreyro not in database
# Country: Instituto de Previsión Social not in database
# Country: Hospital SAMIC Oberá not in database
# Country: Hospital Dr. R. Madariaga not in database
# Country: Hospital SAMIC Eldorado not in database
# Country: CIB-UNEFM not in database
# Country: Programa de Medicina not in database
# Country: Centro Provincial de Higiene y Epidemiología. Matanzas not in database
# Country: Hospital Provincial Militar Docente Mario Muñoz Monroy. Matanzas. E-mail: hmil.mtz@infomed.sld.cu not in database
# Country: Universidad de Ciencias Aplicadas y Ambientales U.D.C.A not in database
# Country: Catholic Bolivian University San Pablo Coroico not in database
# Country: Red de Malnutrición en Iberoamérica Mel-CYTED not in database
# Country: Delegación del Gobierno en Cataluña not in database
# Country: Ministerio de Ciencia e Innovación de España not in database
# Country: Gómez Ulla not in database
# Country: Hospital Son Dureta not in database
# Country: Ministerio de Educación en Ceuta not in database
# Country: PUC do Paraná not in database
# Country: Policlínico Docente Playa Samuel Fernández not in database
# Country: 2) Hospital Provincial Clínico-Quirúrgico Docente José Ramón López Tabrane not in database
# Country: Unidad Oncológica Provincial not in database
# Country: 3) Centro Provincial de Higiene y Epidemiología not in database
# Country: Hospital Territorial General Docente Mario Muñoz Monroy not in database
# Country: Hospital Provincial Militar Docente Mario Muñoz Monroy not in database
# Country: Universidad de Ciencias Médicas Dr. Juan Guiteras Gener not in database
# Country: Universidad de Ciencias Médicas Dr. Juan Guitersa Gener not in database
# Country: Hospital Provincial Docente Gineco Obstétrico Julio Rafael Alfonso Medina not in database
# Country: Laboratório Marcelo Magalhães not in database
# Country: Centro Municipal de Higiene y Epidemiología.Ciénaga de Zapata.matanzas not in database
# Country: Clínica Estomatológica Docente III Congreso PCC not in database
# Country: Hospital Provincial Ginecobstétrico Docente Julio Alfonso Medina not in database
# Country: Hospital Provincial Docente Gineco Obstétrico Julio Rafael Alfonso Medina. Matanzas not in database
# Country: Policlínico Universitario Reynold García. Versalles. Matanzas E-mail: olversalles.mtz@infomed.sld.cu not in database
# Country: Hospital Provincial Pediátrico Docente Eliseo Noel Camaaño not in database
# Country: FCOG (SA) not in database
# Country: Médico Cirujano not in database
# Country: Colegio Médico del Perú not in database
# Country: Departamento Regional de Saúde XII not in database
# Country: Hospital Municipal deOlavarría Dr. Héctor M. Cura not in database
# Country: Hospital Interzonal Gral. deAgudos Vicente López y Planes not in database
# Country: Hospital LucioMolas not in database
# Country: Hospital de Niños Dr.O. Alassia not in database
# Country: Hospital Nacional dePediatría SAMIC Dr. Juan P. Garrahan not in database
# Country: Hospital Provincial Dr. E. Castro Rendón not in database
# Country: Hospital MilitarCentral not in database
# Country: Hospital Municipal Materno Infantil de San Isidro Dr. C.Gianantonio not in database
# Country: Berenson-Allen Center for Noninvasive Brain Stimulation not in database
# Country: Instituto de Tecnologia e Pesquisa not in database
# Country: Institut d´Estudis de la Salut not in database
# Country: Médico Microbiólogo not in database
# Country: - Universidade Comunitária da Região de Chapecó not in database
# Country: programa de pós-graduação em Biocências Aplicadas à Farmácia not in database
# Country: Ministerio Protección Social not in database
# Country: Ministerio de Sanidad y Política Social not in database
# Country: Centro Penitenciario de Pamplona not in database
# Country: Ministerio del Interior not in database
# Country: Centro Penitenciario de Jaén not in database
# Country: Centro Penitenciario de Alcalá-Meco not in database
# Country: Sistema Integrado de Urgencias Médicas Ciudad de La Habana not in database
# Country: Policlínico Universitario Celia Sánchez Manduley not in database
# Country: Centro Provincial de Ciencias Médicas Laudelino González not in database
# Country: Hospital Docente Clínico-Quirúrgico Dr. José Ramón López Tabrane not in database
# Country: Centro Provincial de Higiene y Epidemiología.Matanzas E-mail: labhe.mtz@infomed.sld.cu not in database
# Country: Matanzas. belkysmar.mtz@infomed.sld.cu not in database
# Country: Centro Provincial de Ciencias Médicas Laudelino González.Matanzas.E-mail cpimtz.mtz@infomed.sld.cu not in database
# Country: Universidade Iguaçu not in database
# Country: Colegio de Postgraduados. Campus Montecillo not in database
# Country: Universidad del Mar not in database
# Country: Brazilian Society of Urology not in database
# Country: Instituto de Cardiología de Corrientes Juana Francisca Cabral not in database
# Country: Instituto Nacional de Medicina Legal y Ciencias Forenses not in database
# Country: Universidad de Ciencias Médicas Dr. Juan Guiteras Gener. Matanzas. mercya.mtz@infomed.sld.cu not in database
# Country: Policlínico Docente Samuel Fernández not in database
# Country: Universidad de CIencias Médicas Dr.Juan Guiteras Gener. Matanzas not in database
# Country: Universidad de CIencias Médicas Dr.Juan Guiteras Gener. Matanzas not in database
# Country: Policlínico Facultad Vicente Ponce Carrasco not in database
# Country: Instituto Nacional de Epidemiología not in database
# Country: CEDOES not in database
# Country: Laboratório de Microbiologia Ambiental not in database
# Country: Secretaria Estadual da Saúde Pública do Rio Grande do Norte not in database
# Country: Coordenadoria de Vigilância em Saúde not in database
# Country: Hospital Rivadavia not in database
# Country: Instituto de Ciências Biológicas not in database
# Country: Department of Health of Uberlândia not in database
# Country: Filial Tecnológica 27 de noviembre not in database
# Country: Hospital Territorial Docente Julio M. Aristegui not in database
# Country: Escuela de Medicina y Ciencias de la Salud not in database
# Country: UNESCO not in database
# Country: Fundação de Assistência Médica e Urgência de Contagem not in database
# Country: Comisión de Investigaciones Científicas not in database
# Country: Unidad de Investigación de Atención Primaria de Girona not in database
# Country: Centro de Salud de La Alamedilla not in database
# Country: Atención Primaria. Sector Sanitario de Alcañiz not in database
# Country: Universidad de Manizales not in database
# Country: Universidade Federal de Pelotas (UFPel) not in database
# Country: Organización Panamericana de la Salud not in database
# Country: Hospital Infantil Los Angeles not in database
# Country: ESE Luis Acosta La Union not in database
# Country: Nueva EPS not in database
# Country: Sociedad Venezolana de Periodoncia Capitulo Zuliano not in database
# Country: Miembro de la Sociedad Venezolana de Periodoncia Capitulo Zuliano not in database
# Country: Dirección Regional de Salud Lima not in database
# Country: Kosova not in database
# Country: Universidade de Alfenas not in database
# Country: Instituto de Ciencia y Tecnología Regional (ICTER) not in database
# Country: Hospital Militar e IVSS San José not in database
# Country: Hospital Militar Dr. Carlos Arvelo not in database
# Country: Hospital Universitario Puerta del Mar (HUPM) not in database
# Country: Residencia de Mayores José Matía Calvo not in database
# Country: Região 03 not in database
# Country: Universidade Estadual do Rio Grande no Norte not in database
# Country: Hospital Dr. Luiz Antônio not in database
# Country: URESA not in database
# Country: Hospital Regional de Río Gallegos not in database
# Country: Hospital Regional de Gobernador Gregores not in database
# Country: Instituto Nacional Central Único Coordinador de Ablación e Implante - INCUCAI not in database
# Country: Brasnorte Agropecuária not in database
# Country: Justiça Federal da 3ª região not in database
# Country: Secretaria do Estado de Saúde do Distrito Federal not in database
# Country: Centro Provincial de Retinosis Pigmentaria not in database
# Country: Servicio de Epidemiología y Control de IIH not in database
# Country: Hospital Iván Portuondo not in database
# Country: Policlínica Universitaria Raúl Podio Saborit not in database
# Country: Departamentos de Estomatología y Ortodoncia not in database
# Country: Clínica de Medicina Natural y Tradicional Dr. Mario E.Dihigo y LLanes not in database
# Country: Hospital provincial clínico-Quirúrgico Dr.Jose Ramón López Tabrane not in database
# Country: Dirección Nacional de Estadística de Salud not in database
# Country: Universidad de Ciencias Médicas de Matanzas Dr.Juan Guiteras Gener not in database
# Country: Clínica Docente Carlos Verdugo not in database
# Country: Hospital Provincial Pediátrico Eliseo Noel Caamaño not in database
# Country: Hospital Docente Territorial Iluminado Rodríguez not in database
# Country: Hospital Provincial Militar Mario Muñoz Monroy not in database
# Country: Hospital Provincial Militar Docente Mario Muñoz Monroy not in database
# Country: Hospital Universitario Clínico-Quirúrgico Cmdte Faustino Pérez Hernández not in database
# Country: Hospital Militar Docente Dr.Mario Muñoz Monroy not in database
# Country: CNPq not in database
# Country: Centro de Investigação e Intervenção Social not in database
# Country: Bahia not in database
# Country: Hospital General Docente Iván Portuondo not in database
# Country: UPE not in database
# Country: Instituto de Ciências da Saúde not in database
# Country: Universidade de Chicago not in database
# Country: Municipalidad de San Andrés de Giles not in database
# Country: H.I.G.A. Gral. San Martín not in database
# Country: Centro Universitário Claretiano de Batatais-SP not in database
# Country: Faculdades Integradas de Bebedouro-SP not in database
# Country: University of Calgary not in database
# Country: Fundação Osvaldo Cruz na Amazônia not in database
# Country: Municipal Health Secretariat not in database
# Country: Ministerio de Sanidad y Política Social (España) not in database
# Country: Centro de Investigación Biomédica en Red en Epidemiología y Salud Pública (CIBER-ESP) not in database
# Country: Generalidad de Cataluña not in database
# Country: Hospital Militar Docente Dr. Mario Muñoz Monroy not in database
# Country: HSPE not in database
# Country: Facultad de Ciencias Médicas not in database
# Country: Universidade Sagrado Coração not in database
# Country: Faculdade de Saúde Pública not in database
# Country: Fundação Instituto Oswaldo Cruz not in database
# Country: US Institute of Medicine's Committee not in database
# Country: Hospital Virgen del Camino not in database
# Country: Sociedade Brasileira para o Estudo do Metabolismo Ósseo e Mineral not in database
# Country: UFPB not in database
# Country: Cell International Project member not in database
# Country: Liga de Lucha contra el SIDA not in database
# Country: Gobernación de Santander not in database
# Country: 2Laboratorio Microbiología Hospital Ernesto Guevara not in database
# Country: UFMS not in database
# Country: IPS Especializada Audifarma not in database
# Country: Instituto de Reumatología not in database
# Country: Riesgo de Fractura not in database
# Country: Unidad de Reumatología not in database
# Country: Hospital Universitario Clínica not in database
# Country: Association Nationale des Généralistes pour la Recherche et l'Étude sur l'Hépatopathie Chronique not in database
# Country: Universidad de la República UdelaR not in database
# Country: Unidad Multidisciplinaria de Insuficiencia Cardíaca (UMIC) not in database
# Country: Hospital General de Tampico Doctor Carlos Canseco not in database
# Country: Federal University of Uberlândia not in database
# Country: Sociedade Brasileira de Pneumologia e Tisiologia not in database
# Country: Secretaria Municipal de Saúde de Bauru not in database
# Country: Instituto Tecnológico Autónomo de México not in database
# Country: The Hong Kong and Shanghai Banking Corporation not in database
# Country: Hospital Interzonal Especializado Materno Infantil Dr. Victorio Tetamanti not in database
# Country: Secretaria de Estado da Saúde do Paraná not in database
# Country: Universidade Estadual Santa Cruz not in database
# Country: Prefeitura Municipal de Campinas not in database
# Country: Clínica del Country not in database
# Country: Agência Estadual de Defesa Sanitária Animal e Vegetal not in database
# Country: School of Medicine not in database
# Country: Hematology and Hemotherapy Center of the State of Piauí not in database
# Country: Health Municipal Foundation not in database
# Country: Division of Child and Adolescent Psychiatry not in database
# Country: Hospital de Clínicas not in database
# Country: Asociación de Laboratorios de Alta Complejidad not in database
# Country: Clínica de La Luz not in database
# Country: Facepe not in database
# Country: Ministerio de Salud de Chile not in database
# Country: Unidad de Inmunización y Nuevas vacunas not in database
# Country: Laboratorio de Virología del Instituto de Salud Pública Laboratorio de Virología del Instituto de Salud Pública Laboratorio de Virología del Instituto de Salud Pública de Chile not in database
# Country: División de Planificación Sanitaria not in database
# Country: Secretaria de Saúde do Estado do Rio de Janeiro not in database
# Country: IDIAP Jordi Gol not in database
# Country: Institut Català de la Salut (ICS) not in database
# Country: Clínica de Pavas not in database
# Country: EMCDDA - European Monitoring Centre for Drugs and Drug Addiction not in database
# Country: I.P. - Instituto da Droga e da Toxicodependência not in database
# Country: Instituto Piaget - Campus Académico de Viseu not in database
# Country: UFAL not in database
# Country: UFRPE not in database
# Country: BPSP not in database
# Country: Institut für Parasitologie not in database
# Country: Hospital Central del Instituto de Previsión Social not in database
# Country: UNIMES not in database
# Country: Centro de Atendimento Toxicológico de Campina Grande not in database
# Country: Secretaria Estadual de Saúde de Goiás not in database
# Country: Secretaria Municipal de Saúde de Goiânia not in database
# Country: Secretaria Estadual de Saúde do Estado de Goiás not in database
# Country: Instituto de Altos Estudios en Salud Pública Dr. Arnoldo Gabaldon not in database
# Country: Instituto Superior de de Ciencias Médicas y Preclínicas Victoria de Girón not in database
# Country: Hospital Vita Curitiba not in database
# Country: Centro Dermatologico Federico Lleras Acosta not in database
# Country: United Nations not in database
# Country: EUA not in database
# Country: Alemanha; WFSBP not in database
# Country: DSO National Laboratories not in database
# Country: Centro de Pesquisa do Cacau not in database
# Country: State Veterinary Services not in database
# Country: Nutricionistas Dietistas not in database
# Country: Hospital Aristides Maltez not in database
# Country: Instituto Baiano de Otorrinolaringologia not in database
# Country: Faculdade Estadual de Educação Ciências e Letras de Paranavaí not in database
# Country: Pontifícia Universidade Católica not in database
# Country: CNS not in database
# Country: UNIVALLE not in database
# Country: Departamento de Entomología Tropical not in database
# Country: Sinaloa not in database
# Country: Unidad de salud de Ibagué not in database
# Country: Municipal Hospital Mário Gatti not in database
# Country: Hospital of Clinics not in database
# Country: IB1 not in database
# Country: Faculty of Arts and Sciences not in database
# Country: Rensselaer Polytechnic Institute not in database
# Country: Fundação Instituto Brasileiro de Geografia e Estatística not in database
# Country: Institucional e Comunitária not in database
# Country: Instituto de Pesquisas em Patologias Tropicais de Rondônia not in database
# Country: Secretaria de Estado da Saúde de Rondônia not in database
# Country: Cardiológico Infantil Dr Gilberto Rodríguez Ochoa not in database
# Country: The Research Capacity Program not in database
# Country: CENSIDA not in database
# Country: Hospital de Área El Huecú not in database
# Country: Fundação Municipal de Saúde de Santa Rosa not in database
# Country: Servidor Público Estadual not in database
# Country: Hospital Cardiotrauma Ipanema not in database
# Country: Hospital Carlos van Burén not in database
# Country: Fundación Salamandra not in database
# Country: University of Brasília not in database
# Country: Laboratório Municipal de Cascavel not in database
# Country: Facultad de Ciencias Médicas Filial de Estomatología not in database
# Country: Instituto Nacional de Investigaciones Agrícolas CENIAP-INIA not in database
# Country: Laboratorio Regional de Diagnóstico del Servicio Autónomo de Sanidad Agropecuaria not in database
# Country: Serviço Nacional de Informações e Orientações sobre a Prevenção do Uso Indevido de Drogas - VIVAVOZ not in database
# Country: University of Ottawa not in database
# Country: Facultad de Ciencias Médicas de La Habana (ISCM-H) not in database
# Country: University of Guelph not in database
# Country: Instituto Agronômico de Campinas not in database
# Country: Secretaria Estadual de Saúde de Rondônia not in database
# Country: Tropical Melhoramento & Genética Ltda not in database
# Country: EUA not in database
# Country: Associação Paulista de Medicina de Tráfego not in database
# Country: CEMILFARDEF not in database
# Country: UNIC not in database
# Country: Núcleo de Epidemiologia da Secretaria da Saúde do Estado do Ceará not in database
# Country: Escola Estadual Técnica Guaramano not in database
# Country: Fapeagro not in database
# Country: Microbiologia Veterinária Especial Ltda not in database
# Country: UESC not in database
# Country: Hospital Geral Universitário not in database
# Country: Universidade Comunitária Regional de Chapecó not in database
# Country: EPICLIN not in database
# Country: Hospital Sírio Libanês not in database
# Country: Ministerio de Salud (MINSA) not in database
# Country: Universidade Estadual da Bahia not in database
# Country: Área de Salud Alajuela Sur not in database
# Country: Área rectora de Cartago not in database
# Country: Clínica General de Pavas not in database
# Country: Hospital Cape Town not in database
# Country: Department of Pathology and Forensic Medicine not in database
# Country: CEFET de Química/RJ not in database
# Country: Universidade de Trier not in database
# Country: Centro Latinoamericano de Economía Humana not in database
# Country: Centro de Referência em Saúde do Trabalhador not in database
# Country: Public Health and Ageing Research Group not in database
# Country: Hospital da Cidade de Passo Fundo not in database
# Country: Department of Defense Global Emerging Infections Surveillance and Response System not in database
# Country: Secretaria de Saúde do Estado da Bahia not in database
# Country: Hospital Couto Maia not in database
# Country: Facultad de Ciencias Médicas Dr.Ernesto Che Guevara de la Serna not in database
# Country: Hospital João XXIII not in database
# Country: Sociedade Brasileira de Angiologia e Cirurgia Vascular not in database
# Country: Complejo Hospitalario Universitario de Albacete not in database
# Country: Laboratório de Hantaviroses e Rickettsioses not in database
# Country: Laboratório de Desenvolvimento Tecnológico not in database
# Country: Universidade UNIGRANRIO not in database
# Country: UPCH not in database
# Country: Livestock and Agriculture National Laboratory of Pernambuco not in database
# Country: Foundation Tocantins University not in database
# Country: Fundación del Centro de Estudios Infectológicos not in database
# Country: Hospital Clínico Quirúrgico Docente Provincial Octavio de la Concepción y la Pedraja not in database
# Country: ACC not in database
# Country: Instituto Tomás Reggio not in database
# Country: Clínica Cardiovascular del Niño de Cundinamarca not in database
# Country: HNCH not in database
# Country: Fondo de Población de las Naciones Unidas not in database
# Country: Hospital Universitário Antônio Pedro not in database
# Country: ONUSIDA not in database
# Country: D.F not in database
# Country: Madrid not in database
# Country: Public Health Agency not in database
# Country: Instituto Quirúrgico Del Callao not in database
# Country: Sevilla not in database
# Country: Hospital Central Formosa not in database
# Country: Hospital Provincial de Pediatría not in database
# Country: Universidade de Federal de São Paulo not in database
# Country: Fundacentro not in database
# Country: Clínica Argentina not in database
# Country: Hospital Córdoba not in database
# Country: Hospital Municipal de Agudos Dr. Leónidas Lucero not in database
# Country: Hospital Independencia not in database
# Country: Hospital Interzonal San Juan Bautista not in database
# Country: Hospital Público Descentralizado Dr. Guillermo Rawson not in database
# Country: Hospital del Carmen Mendoza not in database
# Country: Centro de Salud pública Dr. Abraham Lejtman not in database
# Country: USF Barrinha not in database
# Country: Centroamérica y Caribe not in database
# Country: Hospital de Niños de la Santísima Trinidad not in database
# Country: Instituto Nacional de Epidemiología Dr. Juan H. Jara not in database
# Country: Instituto Nacional de Enfermedades Infecciosas (INEI) not in database
# Country: UNJu-Consejo Nacional de Investigaciones Científicas y Técnicas (CONICET); Hospital Ramos Mejía not in database
# Country: UNJu-Consejo Nacional de Investigaciones Científicas y Técnicas (CONICET) not in database
# Country: Centro de Investigaciones Clínica del Country not in database
# Country: PerÃº not in database
# Country: PerÃº not in database
# Country: Sanatorio Mater Dei not in database
# Country: Center for Research on Population not in database
# Country: Blog Bibliovirtual (https://bibliovirtual.wordpress.com/) not in database
# Country: Republica Dominicana not in database
# Country: ACeS Tâmega II/Vale do Sousa Sul not in database
# Country: E.P.E not in database
# Country: Casa Sauza not in database
# Country: Centro de Referencia Nacional de Retinosis Pigmentaria. (CRNRP) not in database
# Country: César Cals Hospital not in database
# Country: Walter Cantídeo Universitary Hospital not in database
# Country: Programa Control de Hidatidosis y Zoonosis de Tierra del Fuego not in database
# Country: E.U.A not in database
# Country: Hospital Vital Brazil not in database
# ...
# Country: 13Hospital Universitario Central de Asturias not in database
# Country: Fundación para el Fomento de la Investigación Sanitaria y Biomédica de la Comunitat Valenciana (FISABIO) not in database
# Country: Consorci Sanitari de l'Anoia not in database
# Country: Hospital Universitario Vall d'Hebron not in database
# Country: Uruguai not in database
# Country: Universidad del Bosque not in database
# Country: Administración Nacional de Laboratorios e institutos de Salud Dr. Carlos G. Malbrán not in database
# Country: Universidad Nacional Arturo Jauretche not in database
# Country: Hospital Dr. Alberto Eurnekian not in database
# Country: Hospital Evita Pueblo not in database
# Country: Dr. Néstor C. Kirchner not in database
# Country: Hospital de Ninos Ricardo Gutiérrez not in database
# Country: Asociación Ciudadana de Lucha Contra las Drogodependencias (ACLAD) not in database
# Country: Servizo Galego de Saude (SERGAS) not in database
# Country: Chris Hani Baragwanath Academic Hospital not in database
# Country: National Research Foundation not in database
# Country: Registro Provincial de Tumores de Mendoza not in database
# Country: Centro Oncológico de Integración Regional (COIR) not in database
# Country: Región Sanitaria de Cortés not in database
# Country: Instituto Nacional de Enfermedades Infecciosas (INEI)-Administración Nacional de Laboratorios e Institutos de Salud not in database
# Country: Instituto Nacional de Enfermedades Respiratorias Dr. Emilio Coni (ANLIS Malbrán) not in database
# Badly written pair:  ['Martínez, María Teresa; Ferreira Capote, Raúl Pablo; Amores Sánchez, Isis; Martínez Piedra, Amarilys; Santana Hernández, Rita Rosa; Gutiérrez Rojas, Ángela Rosa; García Menéndez, Gissel', ' Hospital Clinicoquirúrgico Hermanos Ameijeiras”', '']  Should be exactly 2 elements
# Country: Natural and Social Sciences Research not in database
# Country: Hospital Universitario Son Espases not in database
# Country: Universidad Nacional del Comahue not in database
# Country: Fundación Médica de Río Negro y Neuquén not in database
# Country: Provincia de Santa Fe not in database
# Country: Provincia de Buenos Aires not in database
# Country: Ministerio de Salud de Neuquén not in database
# Country: Universidad Hispanoamericana not in database
# Country: Hospital SAMIC not in database
# Country: Hospital Pediátrico Provincial Dr. Fernando Barreyro not in database
# Country: Ministerio de Salud de la Provincia de Jujuy not in database
# Country: Hospital Departamental de Villavicencio not in database
# Country: Vale do Sousa Sul not in database
# Country: ACeS Grande Porto I not in database
# Country: CICPBA not in database
# Country: Unidad de Investigación CARDIOGOLF not in database
# Country: Centro Hospitalar de São João Porto not in database
# Country: Hospital Universitario de Santander not in database
# Country: Mahalapye District Hospital not in database
# Country: Hospital "Dr. Rafael Ángel Calderón Guardia not in database
# Country: Granma not in database
# Country: Sociedad Uruguaya de Pediatría (SUP) not in database
# Country: Dirección Asociada de Docencia E Investigación not in database
# Country: Gerencia de Atención Primaria not in database
# Country: Conselleria de Sanidad Universal y Salud Pública not in database
# Country: Pathfinder International not in database
# Country: Prisma not in database
# Country: Rwanda Agriculture Board not in database
# Country: Instituto de Altos Estudios Dr. Arnoldo Gabaldon IAE not in database
# Country: Sociedad Venezolana de Puericultura y Pediatría not in database
# Country: La Universidad del Zulia (LUZ) not in database
# Country: Hospital Universitario de Maracaibo (HUM) not in database
# Country: Unidad Programática de Dermatología Sanitaria not in database
# Country: Universidad de Carabobo- Núcleo Aragua not in database
# Country: Instituto Venezolano de Investigaciones Científicas (IVIC) not in database
# Country: Hospital Materno Infantil Samuel Darío Maldonado IVSS not in database
# Country: Dirección Municipal de Salud Distrito Sanitario Revenga not in database
# Country: Universidad de Carabobo Sede-Aragua not in database
# Country: ACeS Amadora not in database
# Country: ACeS Sintra not in database
# Country: Hospital Universitari Dr.Josep Trueta not in database
# Country: Hospital de Clínic not in database
# Country: Hospital Vall d´Hebron not in database
# Country: Hospital Universitario de Gran Canaria Dr.Negrín not in database
# Country: Comité Regional para la Erradicación de la Poliomielitis not in database
# Country: SAP not in database
# Country: Universidad de Montreal not in database
# Country: República Argentina.; Sociedad Europea de Cardiología not in database
# Country: Consejo de enfermedad de Chagas-Mazza not in database
# Country: República Argentina.; Servicio de Cardiología not in database
# Country: Programa Provincial de Dermatología Sanitaria y control de Lepra not in database
# Country: Boliva not in database
# Country: Instituto Navarro de Medicina Legal not in database
# Country: Universidad Nacional del Litoral y del Centro de Estudios Avanzados not in database
# Country: Hospital Ángeles not in database
# Country: Grupo Ángeles not in database
# Country: Institute of Health Policy and Management not in database
# Country: Universidad Estadual de Montes Claros not in database
# Country: UNL-CONICET not in database
# Country: Hospital Infantil Sur Universidad de Ciencias Médicas de Santiago de Cuba not in database
# Country: Hospital Dr. Antonio A. Cetrángolo not in database
# Country: Hospital P. V. de Cordero not in database
# Country: Colômbia not in database
# Country: Italian National Institute for the Evaluation of the Education System (INVALSI) not in database
# Country: University of Rome not in database
# Country: Sociedad Paraguaya de Hipertensión Arterial not in database
# Country: Sociedad Latinoamericana de Hipertensión Arterial not in database
# Country: Sociedad Paraguaya de Nefrología not in database
# Country: Sociedad Paraguaya de Cardiología y Cirugía Cardiovascular not in database
# Country: Sociedad Paraguaya de Diabetología not in database
# Country: Instituto de Previsión Social - Hospital Central not in database
# Country: Sociedad Paraguaya de Medicina Interna not in database
# Country: Hospital General (Alicante) not in database
# Country: Instituto de Investigaciones Biomédicas August Pi i Sunyer (IDIBAPS) not in database
# Country: Hospital Universitario Central (Asturias) not in database
# Country: Gobernación del Magdalena not in database
# Country: Clínica La Merced not in database
# Country: Departamento de Pediatría del Hospital Nacional de Itauguá. Paraguay not in database
# Country: Hospital Nacional de Itauguá. Paraguay not in database
# Country: Hospital Docente Madre Niño San Bartolomé not in database
# Country: Finlandia not in database
# Country: Clínica Briceño Rossi not in database
# Country: Univ.Nac.Centro Prov.Bs.As. (UNCPBA) not in database
# Country: USAL not in database
# Country: Instituto Modelo de Medicina Infantil not in database
# Country: McFarland Clinic not in database
# Country: One Health Initiative not in database
# Country: Iowa State University not in database
# Country: Gobierno de la Provincia de Formosa not in database
# Country: Consorcio de Investigación Biomédica en Red en Epidemiología y Salud Pública (CIBERESP) not in database
# Country: Society of Midwives of South Africa not in database
# Country: Iniversidade Federal de Mato Grosso (UFMT) not in database
# Country: Facultad de Ciencias Médicas Dr. Ernesto Che Guevara de la Serna not in database
# Country: Policlínico Universitario Dr. Ernesto Guevara de la Serna not in database
# Country: Instituto Costarricense de Investigación y Enseñanza Salud y Nutrición (INCIENSA) not in database
# Country: CCSS not in database
# Country: Hospital General Universitario de Elche not in database
# Country: Asociación Española de Pediatría/Asociación Española de Pediatría de Atención Primaria (AEP/AEPap) not in database
# Country: Sociedad Española para el Estudio Interdisciplinar de la Alimentación y los Hábitos Sociales not in database
# Country: Hospital Pediátrico Provincial Docente Pepe Portilla not in database
# Country: Hospital de Leganés not in database
# Country: Hospital Municipal Boliviano Holandés not in database
# Country: Université de Paris-Ouest Nanterre La Défense not in database
# Country: UV not in database
# Country: John F. Kennedy Medical Cente not in database
# Country: CIBER Epidemiología y Salud Pública (CIBERESP) not in database
# Country: Instituto de Medicina Tropical Daniel A. Carrión not in database
# Country: Bénin not in database
# Country: EUA not in database
# Country: EUA not in database
# Country: Frederick Douglass not in database
# Country: Profesional en libre ejercicio not in database
# Country: Asociación Española de Pediatría en Atención Primaria (AEPap) not in database
# Country: Universidad Gran Mariscal de Ayacucho not in database
# Country: Universidad de Munich not in database
# Country: UDELAR not in database
# Country: Consorcio Proyecto Global (PGC) not in database
# Country: Hospital Santa Tecla not in database
# Country: Hospital Distrital de Maternidade Nossa Senhora da Conceição not in database
# Country: Louisiana State University not in database
# Country: Policlínico del Minint. Sancti Spíritus. Cuba not in database
# Country: França not in database
# Country: Centro Hospitalar do Alto Ave not in database
# Country: UNJu. CONICET not in database
# Country: Universidad Católica Andrés Bello not in database
# Country: Corporación de salud del Edo. Táchira not in database
# Country: Hospital Central de San Cristóbal not in database
# Country: Hospital Guachucal not in database
# Country: Hospital Vall d'Hebrón not in database
# Country: Madrid not in database
# Country: Hospital Universitario Dr Negrín not in database
# Country: Hospital Virgen de las Nieves not in database
# Country: MZ not in database
# Country: Catalan Institut of Oncology (ICO) not in database
# Country: Sociedad Científica de San Fernando not in database
# Country: Hospital Nacional de Geriatría y Gerontología not in database
# Country: Universidad de Costa not in database
# Country: Hospital Universitario El Escorial not in database
# Country: Instituto Nacional de Enfermedades Infecciosas (INEI)-ANLIS Dr. Carlos G. Malbrán not in database
# Country: Institut d´Investigació Biomèdica de Bellvitge (IDIBELL) not in database
# Country: ES not in database
# Country: GF not in database
# Country: NL not in database
# Country: Instituto Desarrollo not in database
# Country: Hospital Municipal de Saavedra not in database
# Country: Hospital Municipal de Pigüé not in database
# Country: Hospital de Caridad de Ijuí not in database
# Country: Universidade Regional do Noroeste do Estado do Rio Grande do Sul (UNIJUÍ) not in database
# Country: Migraine & Headache Clinical Development not in database
# Country: Centro de Investigaciones de Campo Dr. Francesco Vitanza not in database
# Country: Instituto de Seguridad y Servicios Sociales de los Trabajadores del Estado (ISSSTE) not in database
# Country: Laboratorio Nacional en Salud: Diagnóstico Molecular y Efecto Ambiental en Enfermedades Crónico- Degenerativas not in database
# Country: Universidad Tecnológica de Pereira-Audifarma S.A not in database
# Country: S.A not in database
# Country: Instituto de Investigação Científica Tropical not in database
# Country: SACOVA Alcoi not in database
# Country: Complejo Hospitalario Insular Materno-Infantil not in database
# Country: Los Andes University not in database
# Country: Hospital Central de la Defensa Gomez Ulla not in database
# Country: Hospital de Cruce not in database
# Country: Hospital Principe de Asturias not in database
# Country: Hospital Vall d´Hebrón not in database
# Country: Hospital Universitario de La Ribera not in database
# Country: CEMIC not in database
# Country: Policlínico Universitario Chiqui Gómez Lubián not in database
# Country: Tygerberg Children's Hospital not in database
# Country: Sunninghill and Waterfall hospitals not in database
# Country: Otorhinolaryngologist at Netcare Linksfield Hospital not in database
# Country: Otorhinolaryngologist at Mediclinic Sandton and Netcare Linksfield Clinic not in database
# Country: Asociación Gull-Lasègue para el estudio y tratamiento de la Anorexia la Bulimia en Canarias not in database
# Country: Universidade de Copenhaga not in database
# Country: USF Conde de Oeiras not in database
# Country: USF do Arco not in database
# Country: Instituto Politécnico Nacional not in database
# Country: Sociedad Latinoamericana de Infectología Pediátrica not in database
# Country: Hospital Dr. Rafael Ángel Calderón Guardia not in database
# Country: Instituto de Medicina Legal y Ciencias Forenses not in database
# Country: Centro de Salud (CS) Valtierra not in database
# Country: Papua New Guinea not in database
# Country: Fluminense Federal University not in database
# Country: Sociedad Española de Nefrología not in database
# Country: Organització Catalana de Trasplantaments not in database
# Country: Rexistro de Enfermos Renais de Galicia (REXER) not in database
# Country: Registro de Enfermos Renales de La Rioja not in database
# Country: Registro de Enfermos Renales en Tratamiento Sustitutivo de Castilla-La Mancha not in database
# Country: Registro de Diálisis y Trasplante de Castilla y León not in database
# Country: Organización Nacional de Trasplantes (ONT) not in database
# Country: Registro de Enfermos Renales de Madrid (REMER) not in database
# Country: Registro de Enfermedades Renales Crónicas de Asturias (RERCA) not in database
# Country: Comunidad Autónoma del País Vasco not in database
# Country: Sistema de Información de la Coordinación Autonómica de Trasplantes de Andalucía (SICATA) not in database
# Country: Registre de Malalts Renals de la Comunidad Valenciana (REMRENAL) not in database
# Country: Registro de Enfermos Renales de Aragón not in database
# Country: Región de los Lagos not in database
# Country: Centro de estancias diurnas Barriomar not in database
# Country: Centro de Salud de Barranda not in database
# Country: Hospital la Vega not in database
# Country: Latin America Project not in database
# Country: SW not in database
# Country: CN not in database
# Country: CN not in database
# Country: AT not in database
# Country: Ditsobotla Service Point not in database
# Country: TA not in database
# Country: TA not in database
# Country: TA not in database
# Country: Sociedad Cubana de Nutrición Clínica y Metabolismo not in database
# Country: Centro de Investigaciones La Libertad-Corpoica not in database
# Country: ISSSTE not in database
# Country: Centro de Estudios Epidemiológicos sobre las Infecciones de Transmisión Sexual y Sida de Cataluña (CEEISCAT) not in database
# Country: Stockholm University not in database
# Country: INEI-ANLIS Dr. Carlos G. Malbrán not in database
# Country: INE Dr. Juan H. Jara - ANLIS Dr. Carlos G. Malbrán not in database
# Country: Cuenta de Alto Costo not in database
# Country: Universidad Católica de Córdoba-CONICET not in database
# Country: Asociación de Clínicas y Sanatorios de la República Argentina not in database
# Country: Hospital Italiano de la Plata not in database
# Country: Instituto Argentino de Diagnóstico y Tratamiento not in database
# Country: Hospital Universitario Departamental de Nariño not in database
# Country: Federación Argentina de Sociedades de Ginecología y Obstetricia not in database
# Country: Federación Argentina de Urología not in database
# Country: Micología y Parasitología Clínica not in database
# Country: Sociedad Argentina de Infectología not in database
# Country: Sociedad Argentina de Urología not in database
# Country: Secretaría Distrital de Integración Social not in database
# Country: ARS Algarve not in database
# Country: Crime and Security Subgroup of Campbell Collaboration not in database
# Country: Hospital General de Agudos Dr. Cosme Argerich not in database
# Country: Instituto de Investigación Sanitaria y Biomédica de Alicante (ISABIAL-Fundación FISABIO) not in database
# Country: Unidad Mixta de Investigación para el Análisis de las Desigualdades en Salud y la Mortalidad FISABIO-UA not in database
# Country: CADENI not in database

# %%
len(authors),len(papers), len(institutions)
# Out:
# (45541, 12596, 8133)

# %% [markdown]
# # Do some analytics

# %%
country_papers_count=swl.get_country_papers_count(papers, institutions)

# %%
country_papers_count
# Out:
# {'Portugal': 172,
#  'Brazil': 5878,
#  'Colombia': 1088,
#  'USA': 507,
#  'Israel': 9,
#  'Serbia': 1,
#  'Spain': 670,
#  'Mexico': 444,
#  'Kenya': 4,
#  'South Africa': 264,
#  'Bolivia': 36,
#  'Argentina': 449,
#  'Peru': 263,
#  'Austria': 5,
#  'Turkey': 21,
#  'Chile': 516,
#  'Uruguay': 77,
#  'China': 47,
#  'Angola': 9,
#  'India': 28,
#  'Indonesia': 3,
#  'Greece': 4,
#  'Czech Republic': 2,
#  'Germany': 29,
#  'Namibia': 3,
#  'Saudi Arabia': 11,
#  'France': 46,
#  'Italy': 39,
#  'Korea': 3,
#  'Japan': 16,
#  'Belgium': 20,
#  'United Kingdom': 137,
#  'Australia': 61,
#  'Mozambique': 16,
#  'Russia': 3,
#  'Ireland': 6,
#  'No country available': 1754,
#  'Cuba': 1106,
#  'Costa Rica': 69,
#  'Nigeria': 11,
#  'Panama': 10,
#  'Dominican Republic': 8,
#  'Honduras': 6,
#  'Guatemala': 14,
#  'El Salvador': 7,
#  'Nicaragua': 8,
#  'Paraguay': 92,
#  'Pakistan': 7,
#  'Venezuela': 258,
#  'Ecuador': 63,
#  'Scotland': 8,
#  'Sri Lanka': 2,
#  'French Guiana': 44,
#  'Poland': 2,
#  'Tunisia': 2,
#  'Tanzania': 11,
#  'Botswana': 3,
#  'Zambia': 6,
#  'Uganda': 6,
#  'Switzerland': 26,
#  'Zimbabwe': 5,
#  'Benin': 14,
#  'Netherlands': 31,
#  'Haiti': 2,
#  'Canada': 51,
#  'Cabo Verde': 3,
#  'Gambia': 10,
#  'Lebanon': 1,
#  'Romania': 5,
#  'Iraq': 3,
#  'Bulgaria': 6,
#  'Denmark': 11,
#  'Grenada': 1,
#  'New Zealand': 2,
#  'Sweden': 8,
#  'Belarus': 1,
#  'Malaysia': 2,
#  'Jamaica': 4,
#  'Qatar': 1,
#  'Moroco': 7,
#  'Jordan': 1,
#  'Egypt': 8,
#  'DR Congo': 3,
#  'Malawi': 3,
#  'Algeria': 5,
#  'Niger': 1,
#  'Vietnam': 7,
#  'Puerto Rico': 3,
#  'Iran': 17,
#  'Trinidad and Tobago': 5,
#  'Papua and Guinea': 2,
#  'Thailand': 7,
#  'Guyana': 1,
#  'Cambodia': 2,
#  'Cameroon': 2,
#  'Croatia': 3,
#  'Taiwan': 3,
#  'Ethiopia': 1,
#  'Lithuania': 1,
#  'Slovakia': 1,
#  'Hungary': 3,
#  'Slovenia': 1,
#  'Malta': 1,
#  'Luxembourg': 1,
#  'Cyprus': 1,
#  'Norway': 6,
#  'Sierra Leone': 1,
#  'Ghana': 3,
#  'Ukraine': 1,
#  'Iceland': 1,
#  'Sudan': 1,
#  'Senegal': 4,
#  'Burkina Faso': 2,
#  'Barbados': 2,
#  'United Arab Emirates': 1,
#  'Philippines': 1,
#  'Nepal': 1,
#  'Kosovo': 1,
#  'North Macedonia': 1,
#  'Finland': 1,
#  'Guinea': 1,
#  'Liberia': 1,
#  'Ivory Coast': 1,
#  'Oman': 1}

# %%
swl.plot_country_papers_time('Brazil', papers, institutions)

# %%
swl.view_inst_papers_hist(institutions)

# %%
swl.plot_country_institutions('Brazil', institutions)

# %%
swl.plot_output_time(papers)

# %%
swl.plot_region_papers_time(['Peru', 'Bolivia', 'Argentina'], papers, institutions)
