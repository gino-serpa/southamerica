# %%
import swl
from pathlib import Path

# %%
data_folder = Path('Data_All')/'epidemiology-scielo'
data_folder = Path('Data_All')/'microbiology-wos'

# %%
df=swl.ingest_folder('wos', data_folder=data_folder)
# Out:
# Data Folder exists:  11  files
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (1).txt
# Encoding unknown. Checking Encoding
# Encoding:  UTF-8-SIG
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (10).txt
# 38
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (2).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (3).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (4).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (5).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (6).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (7).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (8).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs (9).txt
# 500
# * Ingesting file:  Data_All/microbiology-wos/savedrecs.txt
# 500

# %%
 authors, papers, institutions = swl.get_wos_dicts(df)
# Out:
# Country: Kazakhstan not in database
# Possible bad input data:  Panel Experts Metab Disorders Com
# Possible bad input data:  Natl Aids Plan PNS
# Country: Nepal not in database
# Country: Bangladesh not in database
# Country: Philippines not in database
# Country: North Ireland not in database
# Country: Bangladesh not in database
# Country: Bangladesh not in database
# Country: Philippines not in database
# Country: Bangladesh not in database
# Country: Burundi not in database
# Country: Sudan not in database
# Country: San Marino not in database
# Country: Bangladesh not in database
# Country: Philippines not in database
# Country: Bangladesh not in database
# Country: North Ireland not in database
# Possible bad input data:  Acqua Coutinho, Selene Dall'
# Country: Bosnia & Herceg not in database
# Possible bad input data:  Study Grp GESSAGTE
# Country: Bhutan not in database
# Country: Laos not in database
# Possible bad input data:  Acqua Coutinho, Selene Dall'
# Possible bad input data:  CRIPS Investigators
# Possible bad input data:  ESCMID Study Grp Biofilms
# Possible bad input data:  Consulting External Expert Werner
# Country: Monaco not in database
# Country: North Ireland not in database
# Country: Gabon not in database
# Country: Burkina Faso not in database
# Country: Lesotho not in database
# Country: Syria not in database
# Possible bad input data:  Working Grp 1 Seventh European Wor
# Possible bad input data:  Grp Cooperativo Espanol Estudio
# Possible bad input data:  CTCORC
# Possible bad input data:  GASSP-AR Working Grp
# Country: Bosnia & Herceg not in database
# Country: Bangladesh not in database
# Possible bad input data:  AGC
# Possible bad input data:  Argentina Spn Working Grp

# %%
len(authors),len(papers), len(institutions)
# Out:
# (29192, 5022, 6271)

# %%
country_papers_count=swl.get_country_papers_count(papers, institutions)

# %%
country_papers_count
# Out:
# {'Wales': 20,
#  'Chile': 157,
#  'Portugal': 298,
#  'Mexico': 288,
#  'USA': 394,
#  'Spain': 2020,
#  'Brazil': 1347,
#  'South Africa': 28,
#  'Scotland': 48,
#  'Namibia': 4,
#  'China': 44,
#  'New Zealand': 14,
#  'Italy': 202,
#  'Sweden': 81,
#  'Hungary': 13,
#  'Australia': 65,
#  'Switzerland': 89,
#  'France': 204,
#  'Bulgaria': 13,
#  'Denmark': 69,
#  'Germany': 191,
#  'Netherlands': 154,
#  'United Kingdom': 183,
#  'Israel': 37,
#  'Japan': 25,
#  'Colombia': 166,
#  'Cuba': 40,
#  'Belgium': 84,
#  'Argentina': 452,
#  'Austria': 44,
#  'Slovenia': 20,
#  'Greece': 45,
#  'Guinea Bissau': 1,
#  'Estonia': 8,
#  'India': 36,
#  'Saint Kitts and Nevis': 2,
#  'Turkey': 40,
#  'Latvia': 2,
#  'Albania': 4,
#  'Lithuania': 3,
#  'Poland': 25,
#  'Czech Republic': 22,
#  'Croatia': 18,
#  'Peru': 34,
#  'Canada': 70,
#  'Iceland': 5,
#  'Finland': 24,
#  'Malta': 7,
#  'Ireland': 27,
#  'Norway': 32,
#  'Luxembourg': 3,
#  'Uruguay': 17,
#  'Costa Rica': 25,
#  'United Arab Emirates': 2,
#  'Saudi Arabia': 9,
#  'Nigeria': 3,
#  'Azerbaijan': 1,
#  'Russia': 18,
#  'Moroco': 6,
#  'Tunisia': 5,
#  'Bolivia': 2,
#  'Lebanon': 6,
#  'Taiwan': 5,
#  'Korea': 11,
#  'Romania': 23,
#  'Moldova': 1,
#  'Serbia': 12,
#  'Ghana': 2,
#  'Montenegro': 2,
#  'Egypt': 7,
#  'Ukraine': 2,
#  'Zambia': 2,
#  'Ethiopia': 5,
#  'Gambia': 3,
#  'Cameroon': 2,
#  'Pakistan': 4,
#  'Togo': 1,
#  'Iran': 8,
#  'Singapore': 10,
#  'Zimbabwe': 2,
#  'Paraguay': 9,
#  'Indonesia': 5,
#  'Slovakia': 9,
#  'Rwanda': 2,
#  'Madagascar': 2,
#  'Cambodia': 4,
#  'Malawi': 5,
#  'Kenya': 5,
#  'Venezuela': 33,
#  'Ecuador': 13,
#  'Jamaica': 3,
#  'No country available': 24,
#  'Thailand': 12,
#  'Mozambique': 12,
#  'Tanzania': 3,
#  'Vietnam': 3,
#  'Kosovo': 1,
#  'Guatemala': 3,
#  'Qatar': 3,
#  'Panama': 12,
#  'Honduras': 1,
#  'Malaysia': 2,
#  'Palestine': 1,
#  'Belarus': 1,
#  'Nicaragua': 1,
#  'Sri Lanka': 1,
#  'Benin': 1,
#  'Haiti': 2,
#  'Jordan': 1,
#  'Barbados': 3,
#  'Botswana': 2,
#  'Cyprus': 2,
#  'Angola': 2,
#  'Macedonia': 1,
#  'Guinea': 1,
#  'Algeria': 1,
#  'Iraq': 1,
#  'Dominican Republic': 2,
#  'Oman': 1,
#  'Papua and Guinea': 1}

# %%
swl.plot_country_papers_time('Brazil', papers, institutions)

# %%
swl.view_inst_papers_hist(institutions)

# %%
swl.plot_country_institutions('Brazil', institutions)

# %%
swl.plot_output_time(papers)

# %%
swl.plot_region_papers_time(['Peru', 'Bolivia', 'Argentina'], papers, institutions)
